# %% [markdown]
# <a href="https://colab.research.google.com/github/MartinVIllesca/Ramos-Redes/blob/master/CC7221/tarea1/resnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !unzip './drive/My Drive/dataCC7221/Sketch_EITZ.zip'

# %%
import matplotlib as mp
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
import cv2
from tqdm import tqdm
import os
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
def read_data_from_file(str_path, dataset = 'train', shuffle = True):
    """
    Funcion que lee las direcciones de las imagenes y entrega los labels y 
    las direcciones como string, tambien
    las revuelve para aleatoriedad.

    Input:
        string_path:    camino a archivos de dataset
        dataset:        especifica train o test
        shuffle:        booleano que especifica si se revuelve el dataset o no
    Output:
        filenames:      caminos en strings a las imagenes en forma de lista
        labels:         labels en forma de strings
    """

    datafile = os.path.join(str_path, dataset + '.txt')
    assert os.path.exists(datafile)

    with open(datafile) as file :
        lines = [line.strip() for line in file]
        if shuffle:
            random.shuffle(lines)
        _lines = [tuple(line.rstrip().split('\t')) for line in lines]
        filenames, labels = zip(*_lines)
        labels = validate_labels(labels)
        filenames = [os.path.join(str_path, line) for line in filenames]

    return filenames, labels

def validate_labels(labels):
    """
    Funcion que valida los labels, deben ser desde 0 a clases-1
    Input:
        labels:     arreglo de string con los labels
    Output:
        labels:     arreglo de enteros con los labels
    """
    new_labels = [int(label) for label in labels]
    label_set = set(new_labels)
    if (len(label_set) == max(label_set) + 1) and (min(label_set) == 0):
        return new_labels
    else:
        raise ValueError("Algunos labels faltan o estan incorrectos en {}".format(label_set))

# %%
X_train = []
Z = []
img_size = 256
n_channels = 1
nb_classes = 250

# %%
keras.backend.clear_session()

# se debe crear el dataset
data_dir = './Sketch_EITZ'

real_labels = {}
mapping = './Sketch_EITZ/mapping.txt'
with open(mapping) as file:
    for ln in file:
        arg, label = ln.strip().split('\t')
        real_labels[label] = arg

train_images, train_labels = read_data_from_file(data_dir, 'train')
test_images, test_labels = read_data_from_file(data_dir, 'test')

print(train_images[10], real_labels[str(train_labels[10])])

train_images, val_images, y_train, y_val = train_test_split(
        train_images, train_labels, test_size=0.33, random_state=42)

print(train_images[10], real_labels[str(y_train[10])])

a = 'samples\ntrain: {} val: {} test: {}\t'
print(a.format(len(train_images), len(val_images), len(test_images)))

# y_train = crear_diccionario(train_images, y_train)
# y_val = crear_diccionario(val_images, y_val)

# training_generator = DataGenerator(train_images, y_train)
# val_generator = DataGenerator(val_images, y_val)
# Out:
# ./Sketch_EITZ/png_w256/keyboard/9285.png keyboard
# ./Sketch_EITZ/png_w256/tree/18626.png tree
# samples
# train: 10720 val: 5280 test: 4000

# %%
def get_numpy_array(images):
    X = []
    # for idx, img in tqdm(enumerate(images)):
    for img in tqdm(images):
        # if idx % 100 == 0: print('\r{}\t'.format(idx), end='', flush=True)
        # plt.close()
        img = plt.imread(img)
        # print(np.min(img), np.max(img))
        # plt.imshow(img)
        # plt.show()
        X.append(np.reshape(img, (img_size, img_size, n_channels)))
        # X.append(np.array(img))
        # print(img.shape)
        # if idx == 10: break
    X = np.array(X)
    # print(X.shape)
    return X

# %%
X_train = []
X_val = []
X_test = []

X_train = get_numpy_array(train_images)
X_val = get_numpy_array(val_images)
X_test = get_numpy_array(test_images)
# Out:
# 100%|██████████| 10720/10720 [00:08<00:00, 1220.47it/s]
# 100%|██████████| 5280/5280 [00:03<00:00, 1386.15it/s]
# 100%|██████████| 4000/4000 [00:02<00:00, 1416.15it/s]

# %%
# y_train = np.array(y_train).astype('float32')
# y_val = np.array(y_val).astype('float32')
# y_test = np.array(test_labels).astype('float32')
y_train = np.array(y_train)
y_val = np.array(y_val)
y_test = np.array(test_labels)
print(y_train.shape, y_val.shape, y_test.shape)

# y_train = keras.utils.to_categorical(y_train, num_classes=nb_classes)
# y_val = keras.utils.to_categorical(y_val, num_classes=nb_classes)
# y_test = keras.utils.to_categorical(y_test, num_classes=nb_classes)
# print(y_train.shape, y_val.shape, y_test.shape)

# y_train = np.array(y_train).astype('float32')
# y_val = np.array(y_val).astype('float32')
# y_test = np.array(y_test).astype('float32')
# print(y_train.shape, y_val.shape, y_test.shape)
# Out:
# (10720,) (5280,) (4000,)

# %%
print(real_labels)
print(y_train[0])
# Out:
# {'0': 'head', '1': 'human-skeleton', '2': 'chair', '3': 'pretzel', '4': 'shovel', '5': 'leaf', '6': 'parachute', '7': 'house', '8': 'hamburger', '9': 'chandelier', '10': 'tire', '11': 'truck', '12': 'frying-pan', '13': 'lion', '14': 'vase', '15': 'saxophone', '16': 'pen', '17': 'motorbike', '18': 'penguin', '19': 'hammer', '20': 'bush', '21': 'sponge_bob', '22': 'mushroom', '23': 'mouth', '24': 'wheelbarrow', '25': 'seagull', '26': 'cat', '27': 'pigeon', '28': 'cell_phone', '29': 'hat', '30': 'bulldozer', '31': 'toothbrush', '32': 'telephone', '33': 'binoculars', '34': 'flashlight', '35': 'paper_clip', '36': 'van', '37': 'camera', '38': 'crane_machine', '39': 'bee', '40': 'submarine', '41': 'flower_with_stem', '42': 'santa_claus', '43': 'screwdriver', '44': 'comb', '45': 'angel', '46': 'cake', '47': 'cigarette', '48': 'satellite_dish', '49': 'camel', '50': 'backpack', '51': 'bear_animal', '52': 'frog', '53': 'axe', '54': 'ladder', '55': 'wheel', '56': 'mailbox', '57': 'cup', '58': 'lobster', '59': 'parking_meter', '60': 'dog', '61': 'suv', '62': 'fire_hydrant', '63': 'guitar', '64': 'bridge', '65': 'teddy-bear', '66': 'floor_lamp', '67': 'ear', '68': 'crocodile', '69': 'cabinet', '70': 'kangaroo', '71': 'ashtray', '72': 'person_walking', '73': 'satellite', '74': 'computer-mouse', '75': 'lightbulb', '76': 'sea_turtle', '77': 'socks', '78': 'tv', '79': 'standing_bird', '80': 'race_car', '81': 'scorpion', '82': 'fish', '83': 'apple', '84': 'laptop', '85': 'fan', '86': 'giraffe', '87': 'space_shuttle', '88': 'door', '89': 'revolver', '90': 'elephant', '91': 'bed', '92': 'table', '93': 'strawberry', '94': 'door_handle', '95': 'dolphin', '96': 'ant', '97': 'mouse_animal', '98': 'present', '99': 'spider', '100': 'bottle_opener', '101': 'train', '102': 'pineapple', '103': 'couch', '104': 'suitcase', '105': 'rollerblades', '106': 'armchair', '107': 'cannon', '108': 'ship', '109': 'candle', '110': 'harp', '111': 'baseball_bat', '112': 'helmet', '113': 't-shirt', '114': 'key', '115': 'barn', '116': 'alarm_clock', '117': 'car_sedan', '118': 'shark', '119': 'umbrella', '120': 'monkey', '121': 'teapot', '122': 'diamond', '123': 'butterfly', '124': 'bread', '125': 'boomerang', '126': 'foot', '127': 'ice-cream-cone', '128': 'snowboard', '129': 'moon', '130': 'trumpet', '131': 'basket', '132': 'teacup', '133': 'dragon', '134': 'book', '135': 'radio', '136': 'violin', '137': 'rifle', '138': 'wrist-watch', '139': 'bus', '140': 'bathtub', '141': 'tiger', '142': 'duck', '143': 'sword', '144': 'cow', '145': 'pumpkin', '146': 'face', '147': 'octopus', '148': 'donut', '149': 'sun', '150': 'brain', '151': 'syringe', '152': 'pizza', '153': 'helicopter', '154': 'windmill', '155': 'trousers', '156': 'tomato', '157': 'eye', '158': 'keyboard', '159': 'hot_air_balloon', '160': 'airplane', '161': 'shoe', '162': 'sheep', '163': 'wineglass', '164': 'flying_saucer', '165': 'knife', '166': 'carrot', '167': 'snake', '168': 'hedgehog', '169': 'flying_bird', '170': 'cloud', '171': 'skyscraper', '172': 'crown', '173': 'rooster', '174': 'bell', '175': 'bookshelf', '176': 'crab', '177': 'scissors', '178': 'rabbit', '179': 'calculator', '180': 'castle', '181': 'tablelamp', '182': 'tree', '183': 'fork', '184': 'bowl', '185': 'rainbow', '186': 'zebra', '187': 'spoon', '188': 'microphone', '189': 'hourglass', '190': 'walkie_talkie', '191': 'power_outlet', '192': 'bench', '193': 'skull', '194': 'trombone', '195': 'nose', '196': 'person_sitting', '197': 'wine-bottle', '198': 'grapes', '199': 'tractor', '200': 'lighter', '201': 'panda', '202': 'snowman', '203': 'potted_plant', '204': 'ipod', '205': 'eyeglasses', '206': 'pipe_for_smoking', '207': 'head-phones', '208': 'pig', '209': 'arm', '210': 'mermaid', '211': 'squirrel', '212': 'tooth', '213': 'piano', '214': 'beer-mug', '215': 'loudspeaker', '216': 'skateboard', '217': 'owl', '218': 'toilet', '219': 'stapler', '220': 'purse', '221': 'envelope', '222': 'sailboat', '223': 'mug', '224': 'blimp', '225': 'streetlight', '226': ...
# 195

# %%
n = 1000
# print(np.where(y_train[n] == 1)[0])
# plt.imshow(X_train[np.where(y_train[n] == 1)[0][0]].reshape((img_size,img_size)))
# plt.show()
# print(real_labels[str(np.where(y_train[n] == 1)[0][0])])

print(y_train[n])
plt.imshow(X_train[n].reshape((img_size,img_size)))
plt.show()
print(real_labels[str(y_train[n])])
# Out:
# 37
# camera

# %%
def resnet_block(x, n_neurons, first=False):

  if not first:
    x = layers.BatchNormalization()(x)
    x1 = layers.Conv2D(1, (3,3), padding='same',
                      strides=2,
                      kernel_initializer='he_normal',
                      activation=None)(x)

    x = layers.Conv2D(n_neurons, (3,3), padding='same',
                      strides=2,
                      kernel_initializer='he_normal',
                      activation='relu')(x)
  else:
    x1 = x

    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(n_neurons, (3,3), padding='same',
                      kernel_initializer='he_normal',
                      activation='relu')(x)


  x = layers.BatchNormalization()(x)
  x = layers.Conv2D(n_neurons, (3,3), padding='same',
                    kernel_initializer='he_normal')(x)
  
  x2 = layers.ReLU()(x + x1)


  x = layers.BatchNormalization()(x2)
  x = layers.Conv2D(n_neurons, (3,3), padding='same',
                    kernel_initializer='he_normal',
                    activation='relu')(x)

  x = layers.BatchNormalization()(x)
  x = layers.Conv2D(n_neurons, (3,3), padding='same',
                    kernel_initializer='he_normal')(x)

  return x + x2

# %%
inputs = keras.Input(shape=(img_size, img_size, n_channels))

x = layers.BatchNormalization()(inputs)
x = layers.Conv2D(64, (3,3), padding='same', strides=2,
                  kernel_initializer='he_normal',
                  activation='relu')(x)

print(1)
x = resnet_block(x, 64, True)
x = layers.Dropout(rate=0.5)(x)
print(2)
x = resnet_block(x, 64)
x = layers.Dropout(rate=0.5)(x)
print(3)
x = resnet_block(x, 128)
x = layers.Dropout(rate=0.5)(x)
print(4)
x = resnet_block(x, 128)
x = layers.Dropout(rate=0.5)(x)
print(5)
x = resnet_block(x, 256)
x = layers.Dropout(rate=0.2)(x)

x = layers.GlobalAveragePooling2D()(x)

x = layers.BatchNormalization()(x)
x = layers.Dense(250)(x)

model = keras.Model(inputs, x, name='resnet')
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
print(model.summary())
# Out:
# Model: "resnet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 1)  4           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 64) 640         batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 64) 36928       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 64) 36928       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOp [(None, 128, 128, 64 0           conv2d_2[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 128, 128, 64) 0           tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 64) 256         re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 64) 36928       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 64) 36928       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_1 (TensorFlow [(None, 128, 128, 64 0           conv2d_4[0][0]
#                                                                  re_lu[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 128, 64) 0           tf_op_layer_AddV2_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 128, 64) 256         dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 64)   36928       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 64)   36928       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 1)    577         batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_2 (TensorFlow [(None, 64, 64, 64)] 0           conv2d_7[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 64, 64, 64)   0           tf_op_layer_AddV2_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 64)   256         re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 64)   36928       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 64, 64, 64)   36928       batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_3 (TensorFlow [(None, 64, 64, 64)] 0           conv2d_9[0][0]
#                                                                  re_lu_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 64)   0           tf_op_layer_AddV2_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64, 64, 64)   256         dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 128)  73856       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 128)  147584      batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 1)    577         batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_4 (TensorFlow [(None, 32, 32, 128) 0           conv2d_12[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 32, 32, 128)  0           tf_op_layer_AddV2_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 128)  512         re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 128)  147584      batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 128)  147584      batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_5 (TensorFlow [(None, 32, 32, 128) 0           conv2d_14[0][0]
#                                                                  re_lu_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 128)  0           tf_op_layer_AddV2_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 128)  512         dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 128)  147584      batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 128)  147584      batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 1)    1153        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_6 (TensorFlow [(None, 16, 16, 128) 0           conv2d_17[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 16, 16, 128)  0           tf_op_layer_AddV2_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 128)  512         re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 128)  147584      batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 16, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 128)  147584      batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_7 (TensorFlow [(None, 16, 16, 128) 0           conv2d_19[0][0]
#                                                                  re_lu_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 128)  0           tf_op_layer_AddV2_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 16, 128)  512         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 256)    295168      batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 256)    1024        conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 256)    590080      batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 1)      1153        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_8 (TensorFlow [(None, 8, 8, 256)]  0           conv2d_22[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 8, 8, 256)    0           tf_op_layer_AddV2_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 8, 8, 256)    1024        re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 8, 256)    590080      batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 8, 8, 256)    1024        conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 8, 256)    590080      batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_9 (TensorFlow [(None, 8, 8, 256)]  0           conv2d_24[0][0]
#                                                                  re_lu_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 256)    0           tf_op_layer_AddV2_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 256)          0           dropout_4[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 256)          0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 256)          1024        flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 250)          64250       batch_normalization_21[0][0]
# ==================================================================================================
# Total params: 3,546,626
# Trainable params: 3,541,376
# Non-trainable params: 5,250
# __________________________________________________________________________________________________
# None

# %%
keras.utils.plot_model(model, './BasicVGG.png', show_shapes=True, expand_nested=True)

# %%
model.compile(optimizer=keras.optimizers.Adam(),
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
print(y_train.shape, X_train.shape)
# Out:
# (10720,) (10720, 256, 256, 1)

# %%
# new_model = keras.models.load_model('./drive/My Drive/dataCC7221/model.50-4.91.h5')

# %%
# new_model.summary()

# %%
# loss, acc = new_model.evaluate(X_test, y_test, verbose=2)
# print('Restored model, accuracy: {:5.2f}%'.format(100*acc))

# %%
# callbacks
callbacks = [
    keras.callbacks.EarlyStopping(patience=10),
    keras.callbacks.ModelCheckpoint(filepath='drive/My Drive/dataCC7221/model1resnet_drop2/model.{epoch:02d}-{val_loss:.2f}.h5',
                                    save_best_only=True),
    keras.callbacks.TensorBoard(log_dir='./drive/My Drive/dataCC7221/model1resnet_drop2/logs')
]

# %%
history = model.fit(X_train, y_train,
                    batch_size=32,
                    epochs=100,
                    validation_data=(X_val, y_val),
                    validation_batch_size=32,
                    callbacks=callbacks)
# Out:
# Epoch 1/100
# 335/335 [==============================] - 112s 335ms/step - loss: 4.9485 - accuracy: 0.0368 - val_loss: 4.7338 - val_accuracy: 0.0578
# Epoch 2/100
# 335/335 [==============================] - 112s 333ms/step - loss: 4.2318 - accuracy: 0.1059 - val_loss: 4.5455 - val_accuracy: 0.0989
# Epoch 3/100
# 335/335 [==============================] - 112s 334ms/step - loss: 3.5746 - accuracy: 0.2108 - val_loss: 3.5839 - val_accuracy: 0.2131
# Epoch 4/100
# 335/335 [==============================] - 112s 333ms/step - loss: 2.9878 - accuracy: 0.3134 - val_loss: 3.2018 - val_accuracy: 0.2939
# Epoch 5/100
# 335/335 [==============================] - 111s 332ms/step - loss: 2.4894 - accuracy: 0.4099 - val_loss: 3.2442 - val_accuracy: 0.3140
# Epoch 6/100
# 335/335 [==============================] - 112s 333ms/step - loss: 2.0653 - accuracy: 0.4929 - val_loss: 2.7162 - val_accuracy: 0.3830
# Epoch 7/100
# 335/335 [==============================] - 112s 333ms/step - loss: 1.6823 - accuracy: 0.5783 - val_loss: 2.4088 - val_accuracy: 0.4456
# Epoch 8/100
# 335/335 [==============================] - 111s 333ms/step - loss: 1.3514 - accuracy: 0.6500 - val_loss: 2.3697 - val_accuracy: 0.4532
# Epoch 9/100
# 335/335 [==============================] - 111s 332ms/step - loss: 0.9938 - accuracy: 0.7345 - val_loss: 2.4104 - val_accuracy: 0.4661
# Epoch 10/100
# 335/335 [==============================] - 111s 332ms/step - loss: 0.6908 - accuracy: 0.8145 - val_loss: 2.3784 - val_accuracy: 0.4818
# Epoch 11/100
# 335/335 [==============================] - 111s 331ms/step - loss: 0.4455 - accuracy: 0.8828 - val_loss: 2.4411 - val_accuracy: 0.4903
# Epoch 12/100
# 335/335 [==============================] - 111s 331ms/step - loss: 0.3006 - accuracy: 0.9244 - val_loss: 2.4958 - val_accuracy: 0.4795
# Epoch 13/100
# 335/335 [==============================] - 111s 332ms/step - loss: 0.2033 - accuracy: 0.9502 - val_loss: 2.6377 - val_accuracy: 0.4830
# Epoch 14/100
# 335/335 [==============================] - 111s 332ms/step - loss: 0.1698 - accuracy: 0.9576 - val_loss: 2.7177 - val_accuracy: 0.4926
# Epoch 15/100
# 335/335 [==============================] - 111s 332ms/step - loss: 0.1377 - accuracy: 0.9657 - val_loss: 2.7609 - val_accuracy: 0.4737
# Epoch 16/100
# 335/335 [==============================] - 111s 332ms/step - loss: 0.1173 - accuracy: 0.9708 - val_loss: 3.0407 - val_accuracy: 0.4650
# Epoch 17/100
# 335/335 [==============================] - 111s 332ms/step - loss: 0.1344 - accuracy: 0.9641 - val_loss: 3.0101 - val_accuracy: 0.4805
# Epoch 18/100
# 335/335 [==============================] - 111s 332ms/step - loss: 0.1250 - accuracy: 0.9660 - val_loss: 3.1906 - val_accuracy: 0.4688

# %%
# best_model = keras.models.load_model('./drive/My Drive/dataCC7221/modelVGGBasic/model.08-2.18.h5')
# loss, acc = best_model.evaluate(X_test, y_test, batch_size=32)
# print('acc: {:.3f}\t loss: {:.3f}'.format(acc, loss))
# loss, acc = model.evaluate(X_test, y_test, batch_size=32)
# print('acc: {:.3f}\t loss: {:.3f}'.format(acc, loss))

# %%
# save history
import pickle
with open('./drive/My Drive/dataCC7221/trainHistoryDict_resnet_drop2', 'wb') as file_pi:
  pickle.dump(history.history, file_pi)

# %%
# !mkdir './drive/My Drive/data7221/saved_model/'
# model.save('./drive/My Drive/data7221/saved_model/')

# %%
# np.load('./drive/My Drive/dataCC7221/trainHistoryDict_resnet', allow_pickle=True)
